# %%
import matplotlib.pyplot as plt
import json
from common import *

data_file = open("./results.json", "r")

data = json.load(data_file)

# Temps en fonction du nombre d'élément pour chacune des approche
times = {}

data_pb1 = data["./pb/pb1.pb"]
times[1] = [(int(nbT), data_pb1[nbT]["time"]) for nbT in data_pb1]

data_pb2 = data["./pb/pb2.pb"]
times[2] = [(int(nbT), data_pb2[nbT]["time"]) for nbT in data_pb2]

data_pb6 = data["./pb/pb6.pb"]
times[6] = [(int(nbT), data_pb6[nbT]["time"]) for nbT in data_pb6]
# Out:
# (1, 0.32406527)
# (2, 0.19672470000000003)
# (3, 0.14888366000000006)
# (4, 0.12003364999999994)
# (5, 0.11258232)
# (6, 0.09530076999999997)
# (7, 0.08837463999999998)
# (8, 0.08859447000000001)
# (9, 0.10879032000000004)
# (10, 0.10221516999999998)
# (11, 0.09884456999999999)
# (12, 0.09371289999999999)
# (13, 0.08739626000000002)
# (14, 0.08480158999999998)
# (15, 0.08582016000000003)
# (16, 0.09263982000000003)

# %%
pb1_times = [t[1] for t in times[1]]

plt.bar(range(1,NB_THREAD_MAX+1) ,pb1_times, label="_ignore")
plt.xlabel("Nombre de thread")
plt.ylabel("Temps en second")
# plt.title(f"Temps pris par l'implémentation \"réduction simple\" en fonction du nombre de thread pour {TEST_SIZE[-1]} éléments.")

plt.savefig("./images/pb1_times.svg")
plt.show()

# %%
pb2_times = [t[1] for t in times[2]]

plt.bar(range(1,NB_THREAD_MAX+1) ,pb2_times, label="_ignore")
plt.xlabel("Nombre de thread")
plt.ylabel("Temps en second")
# plt.title(f"Temps pris par l'implémentation \"réduction simple\" en fonction du nombre de thread pour {TEST_SIZE[-1]} éléments.")

plt.savefig("./images/pb2_times.svg")
plt.show()

# %%
pb6_times = [t[1] for t in times[6]]

plt.bar(range(1,NB_THREAD_MAX+1) ,pb6_times, label="_ignore")
plt.xlabel("Nombre de thread")
plt.ylabel("Temps en second")
# plt.title(f"Temps pris par l'implémentation \"réduction simple\" en fonction du nombre de thread pour {TEST_SIZE[-1]} éléments.")

plt.savefig("./images/pb6_times.svg")
plt.show()
